# %% [markdown]
# ## Self-Assessment
# - I thoroughly understood the content of the fifth lecture and completed all assigned exercises.
# - The concept of **REGEX** was a refresher and also some of the nuances like **ravel** and **flatten** was new to me
# - The concepts were clear and well-structured, which allowed me to apply the coding norms confidently.
# - I now have a fair understanding of how to write scripts for the markdown cells and have taken less help from the AI tools, unlike the first assignment.
#
# ## Problems Faced While Completing the Exercises
# - Content Generation and Structure: Utilized ChatGPT and Gemini to assist in creating the professional markdown files with clear formatting and structure.

# %% [markdown]
# ## Assignment Number 7.23 Data Science: Pandas DataFrames
# ### LabAssist: Model your code after the code examples in Section 7.14.2

# %% [markdown]
# **(a)** Create a DataFrame named temperatures from a dictionary of three temperature readings each for 'Maxine', 'James' and 'Amanda'

# %%
##importing the necessary modules
import numpy as nm
import pandas as pd

# %%
three_temp = {
    'Maxine': [100, 90, 110],
    'James': [95, 87, 120],
    'Amanda': [110, 84, 79]
}
temperatures = pd.DataFrame(three_temp)
temperatures
# Out:
#    Maxine  James  Amanda
# 0     100     95     110
# 1      90     87      84
# 2     110    120      79

# %% [markdown]
# ### Explanation
# - First create a list with key-value pair
# - Assign the created dictionary to the datframe object through panda

# %% [markdown]
# **(b)** Recreate the DataFrame temperatures in Part (a) with custom indices using the index keyword argument and a list containing 'Morning', 'Afternoon' and 'Evening'.

# %%
temperatures = pd.DataFrame(three_temp, index=['Morning', 'Afternoon', 'Evening'])
temperatures
# Out:
#            Maxine  James  Amanda
# Morning       100     95     110
# Afternoon      90     87      84
# Evening       110    120      79

# %% [markdown]
# ### Explanation
# - The dataframe gives an option to customize the index for the dataframe using the specified custom indices with the index keyword argument after we created the DataFrame

# %% [markdown]
# **(c)** Select from temperatures the column of temperature readings for 'Maxine'

# %%
temperatures['Maxine']
# Out:
# Morning      100
# Afternoon     90
# Evening      110
# Name: Maxine, dtype: int64

# %% [markdown]
# ### Explanation
# - Use DataFrame’s column-name strings as attributes and retrieve the column data

# %% [markdown]
# **(d)** Select from temperatures the row of 'Morning' temperature readings.

# %%
temperatures.loc['Morning']
# Out:
# Maxine    100
# James      95
# Amanda    110
# Name: Morning, dtype: int64

# %% [markdown]
# ### Explanation
# - **loc** gives access to the row by using data frame's label

# %% [markdown]
# **(e)** Select from temperatures the rows for 'Morning' and 'Evening' temperature readings

# %%
temperatures.loc[['Morning','Evening']]
# Out:
#          Maxine  James  Amanda
# Morning     100     95     110
# Evening     110    120      79

# %% [markdown]
# ### Explanation
# - To select specific rows, use a list of the dataframe and specify the row names which you want to get the output for

# %% [markdown]
# **(f)** Select from temperatures the columns of temperature readings for 'Amanda' and 'Maxine'

# %%
temperatures[['Amanda','Maxine']]
# Out:
#            Amanda  Maxine
# Morning       110     100
# Afternoon      84      90
# Evening        79     110

# %% [markdown]
# **(g)** Select from temperatures the elements for 'Amanda' and 'Maxine' in the 'Morning' and 'Afternoon'.

# %%
temperatures.loc['Morning':'Afternoon', 'Maxine':'Amanda']
# Out:
#            Maxine  James  Amanda
# Morning       100     95     110
# Afternoon      90     87      84

# %% [markdown]
# **(h)** Use the describe method to produce temperatures’ descriptive statistics

# %%
temperatures.describe()
# Out:
#        Maxine       James      Amanda
# count     3.0    3.000000    3.000000
# mean    100.0  100.666667   91.000000
# std      10.0   17.214335   16.643317
# min      90.0   87.000000   79.000000
# 25%      95.0   91.000000   81.500000
# 50%     100.0   95.000000   84.000000
# 75%     105.0  107.500000   97.000000
# max     110.0  120.000000  110.000000

# %% [markdown]
# ### Explanation
# - The describe function of the dataframe gives an entire list of descriptive statistics

# %% [markdown]
# **(i)** Transpose temperatures

# %%
temperatures.T
# Out:
#         Morning  Afternoon  Evening
# Maxine      100         90      110
# James        95         87      120
# Amanda      110         84       79

# %% [markdown]
# ### Explanation
# - Transpose the so called rows and columns of the dataframe to -> the rows become the columns, and the columns become the rows—by using the T attribute

# %% [markdown]
# **(j)** Sort temperatures so that its column names are in alphabetical order

# %%
temperatures.sort_index( axis = 1)
# Out:
#            Amanda  James  Maxine
# Morning       110     95     100
# Afternoon      84     87      90
# Evening        79    120     110

# %% [markdown]
# ### Explanation
# - Sort the columns into ascending order (left-to-right) by data frame's column names.
# - Passing the axis=1 keyword argument indicates that we wish to sort the column indices

# %% [markdown]
# # Assignment Number 8.3 (Pig Latin)
# **Exercise Description**
# - Write a script that encodes English-language phrases into a form of coded language called pig Latin.
# - There are many different ways to form pig Latin phrases.
# - For simplicity, use the following algorithm:
#     - To form a pig Latin phrase from an English-language phrase, tokenize the phrase into words with string method split.
#     -  To translate each English word into a pig Latin word, place the first letter of the English word at the end of the word and add the letters “ay.”
#         - Thus, the word “jump” becomes “umpjay,” the word “the” becomes “hetay,” and the word “computer” becomes “omputercay.” If the word starts with a vowel, just add “ay.”
#        -  Blanks between words remain as blanks.
#        -  Assume the following:
#                - The English phrase consists of words separated by blanks, there are no punctuation marks and all words have two or more                  letters.
#
# - Enable the user to enter a sentence, then display the sentence in pig Latin.
#
# **LabAssist:**
# -  Remember that strings can be sliced like lists

# %%
def pig_latin(sentence):
    """
    Converts a sentence into Pig Latin.

    Each word is transformed by moving its first letter to the end
    and adding 'ay'. Returns the resulting sentence.
    """
    words = sentence.split()
    pig_latin_words = [word[1:] + word[0] + 'ay' for word in words]
    return ' '.join(pig_latin_words)

# %%
check = 'Y'
while check.upper() == 'Y':
    sentence = input("Enter the sentence to convert into Pig Latin: ").strip()
    converted_string = pig_latin(sentence)
    print(f'The resulting converted string in Pig Latin is: "{converted_string}"')
    check = input('Do you wish to continue (Y/N)? ').strip()

print('Thank you for interaction.')
# Out:
# Enter the sentence to convert into Pig Latin:  India wins the world cup
# The resulting converted string in Pig Latin is: "ndiaIay insway hetay orldway upcay"
# Do you wish to continue (Y/N)?  N
# Thank you for interaction.

# %% [markdown]
# ## Explanation
#
# - The function **pig_latin** converts the user inputted string in Pig latin format
# - The function **.split()** used in the function is used to conver the string into a list of indivisual words
#     - For example sentence is **Hello World**. the split function returns ['hello','world'] as output
# - The Method iterates for each word and then returns the concatenated string
#     - The **' '.join** keyword used is used to concatenate the strings into one
# - The main logic for the program ass users to input the sentence for the conversion
# - It calls the defined function and then returns the output int he desired format of **Pig Latin**

# %% [markdown]
# # Assignment Number 8.8 Converting Integers to Emojis —
#
# - Display 10 emojis beginning with the smiley face, which has the value 0x1F600:5
# - The value 0x1F600 is a hexadecimal (base 16) integer.
# - See the online appendix “Number Systems” for information on the hexadecimal number system.
# - You can find emoji codes by searching online for “Unicode full emoji list.”
# - The Unicode website precedes each character code with "U+" (representing Unicode).
# - Replace "U+" with "0x" to properly format the code as a Python hexadecimal integer
#
# ## LabAssist: For fun, go to
#  - [Full Emoji List](https://unicode.org/emoji/charts/full-emoji-list.html) research the ranges of Unicode values for all emoji characters and try to print them all.
# - **Does your system support all of them?**

# %%
## the value 0x1F600 is a hexadecimal (base 16) integer for the first smiley to be displayed
start_emoji = 0x1F600

# Number of emojis to display
num_emojis = 10

# Print 10 consecutive emojis starting from 😀
for code in range(start_emoji, start_emoji + num_emojis):
     print(f'{code:c}', end=' ')
# Out:
# 😀 😁 😂 😃 😄 😅 😆 😇 😈 😉

# %% [markdown]
# ## Explanation
# - **f'{code:c}** is used to convert the hexadecimal integer to its respective smiley character
# - The main code only prints the first 10 smiley characters which can be scaled to more characters to be displayed
