# %% [markdown]
# ## Self-Assessment
# - I thoroughly understood the content of the fifth lecture and completed all assigned exercises.
# - The concept of **REGEX** was a refresher and also some of the nuances like **ravel** and **flatten** was new to me
# - The concepts were clear and well-structured, which allowed me to apply the coding norms confidently.
# - I now have a fair understanding of how to write scripts for the markdown cells and have taken less help from the AI tools, unlike the first assignment.
#
# ## Problems Faced While Completing the Exercises
# - Content Generation and Structure: Utilized ChatGPT and Gemini to assist in creating the professional markdown files with clear formatting and structure.

# %% [markdown]
# ## Assignment Number 9.16 Data Science: Working with the diamonds.csv

# %%
##importing the necessary modules
import numpy as nm
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **(a)** Download diamonds.csv from one of the datset repositories
# **(b)** Load the dataset into a pandas DataFrame with the following statement, which uses the fiorst column of each record as the row index :
#    -    ( 'diamonds.csv' , index_col=0)

# %%
diamonds = pd.read_csv('diamonds.csv' , index_col=0)

# %% [markdown]
# **(c)** Display the first seven rows of the data Frame

# %%
diamonds.head(7)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %% [markdown]
# **(d)** Display the last seven rows of the data Frame

# %%
diamonds.tail(7)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# **(e)** Use the datafram method **describe** ( which looks at the numerical columns) to calculate the descriptive statistics for the numerical coluns - carat , depth , table , price , x , y and z

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# **(f)** Use Series method descrive to calculate the descriptive statistics for the categorical data( text) columns - cut , color and clarity

# %%
categorical_columns = ['cut', 'color', 'clarity']
diamonds[categorical_columns].describe()
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# **(g)** What are the unique category values

# %%
categorical_columns = ['cut', 'color', 'clarity']
for columns in categorical_columns:
    print(f"\n{col} -> unique values in categories :",  pd.Series(diamonds[columns]).unique())
# ...existing code...
# Out:
# clarity -> unique values in categories : ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
#
# clarity -> unique values in categories : ['E' 'I' 'J' 'H' 'F' 'G' 'D']
#
# clarity -> unique values in categories : ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %% [markdown]
# **(h)** Pandas has many capabilities.
# -   Execute the %matplotlib magic to enable Matplotlib support in Ipython.
# -   Then to view histogramns or each numerical data call your DataFrame's hist method
# -   Display the histograms for the seven numerical columns

# %%
# %matplotlib inline
diamonds.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# ## Assignment Number 10.2 Account Class with Read-Only Properties —
#
# ### LabAssist: Use the syntax for property getters shown in Section 10.4.2’s Time class

# %% [markdown]
# -   Modify the existing Accout Class to provide read ony property for **name** and **balance**
# - Re-execute to test your updated class, to show the name and balance are read only

# %%
# account.py
"""Account class definition."""
from decimal import Decimal

class Account:
    """Account class for maintaining a bank account balance."""
    
    def __init__(self, name, balance):
        """Create and initialize an Account object."""

        # if balance is less than 0.00, raise an exception
        if balance < Decimal('0.00'):
            raise ValueError('Initial balance must be >= 0.00.')

        self.name = name
        self.balance = balance
        
    def deposit(self, amount):
        """Deposit money to the account."""

        # if amount is less than 0.00, raise an exception
        if amount < Decimal('0.00'):
            raise ValueError('amount must be positive.')

        self.balance += amount


add_details = Account('Pranit Kumar', Decimal('1000.00'))
print(f'Account holder name: {add_details.name}')
print(f'Account balance: {add_details.balance}')    

# Trying to modify the property 
add_details.name = 'John Doe'
add_details.balance = 500.00
print(f'Account holder name after modification attempt: {add_details.name}')
print(f'Account balance after modification attempt: {add_details.balance}')
# Out:
# Account holder name: Pranit Kumar
# Account balance: 1000.00
# Account holder name after modification attempt: John Doe
# Account balance after modification attempt: 500.0

# %% [markdown]
# **Change the Class Variable using underscore**

# %%
# account.py
"""Account class definition."""
from decimal import Decimal

class Account:
    """Account class for maintaining a bank account balance."""
    
    def __init__(self, name, balance):
        """Create and initialize an Account object."""

        # if balance is less than 0.00, raise an exception
        if balance < Decimal('0.00'):
            raise ValueError('Initial balance must be >= 0.00.')

        self._name = name
        self._balance = balance
        
    def deposit(self, amount):
        """Deposit money to the account."""

        # if amount is less than 0.00, raise an exception
        if amount < Decimal('0.00'):
            raise ValueError('amount must be positive.')

        self._balance += amount

    @property
    def name(self):
        """Get the account holder's name."""
        return self._name
    @property
    def balance(self):
        """Get the account balance."""
        return self._balance

add_details = Account('Pranit Kumar', Decimal('1000.00'))
print(f'Account holder name: {add_details.name}')
print(f'Account balance: {add_details.balance}')    

# Trying to modify the property
try:
    add_details.name = 'John Doe'
except AttributeError as e:
    print("Error:", e)

try:
    add_details.balance = 50000
except AttributeError as e:
    print("Error:", e)
# Out:
# Account holder name: Pranit Kumar
# Account balance: 1000.00
# Error: property 'name' of 'Account' object has no setter
# Error: property 'balance' of 'Account' object has no setter

# %% [markdown]
# ## Assignment Number 10.5 Duck Typing —
#
# ### LabAssist: For class SalariedEmployee, you can mimic much of the syntax and code in class CommissionEmployee

# %%
"""CommissionEmployee base class."""
from decimal import Decimal
from typing import override

class CommissionEmployee:
    """An employee who gets paid commission based on gross sales."""

    def __init__(self, name, gross_sales, commission_rate):
        """Initialize CommissionEmployee's attributes."""
        self._name = name
        self.gross_sales = gross_sales  # validate via property
        self.commission_rate = commission_rate  # validate via property

    @property
    def name(self):
        return self._name

    @property
    def gross_sales(self):
        return self._gross_sales

    @gross_sales.setter
    def gross_sales(self, sales):
        """Set gross sales or raise ValueError if invalid."""
        if sales < Decimal('0.00'):
            raise ValueError('Gross sales must be >= to 0')
        
        self._gross_sales = sales
        
    @property
    def commission_rate(self):
        return self._commission_rate

    @commission_rate.setter
    def commission_rate(self, rate):
        self._commission_rate = rate

    def earnings(self):
        """Calculate earnings."""   
        return self.gross_sales * self.commission_rate

    @override
    def __repr__(self):
        """Return string representation for repr()."""
        return (f'CommissionEmployee: {self.name}\n' + 
            f'gross sales: {self.gross_sales:.2f}\n' +
            f'commission rate: {self.commission_rate:.2f}')

# %%
# salariedcommissionemployee.py
"""SalariedCommissionEmployee derived from CommissionEmployee."""
from commissionemployee import CommissionEmployee
from decimal import Decimal
from typing import override

class SalariedCommissionEmployee(CommissionEmployee):
    """An employee who gets paid a salary plus 
    commission based on gross sales."""

    def __init__(self, name, gross_sales, commission_rate, base_salary):
        """Initialize SalariedCommissionEmployee's attributes."""
        super().__init__(name, gross_sales, commission_rate)
        self.base_salary = base_salary  # validate via property

    @property
    def base_salary(self):
        return self._base_salary

    @base_salary.setter
    def base_salary(self, salary):
        """Set base salary or raise ValueError if invalid."""
        if salary < Decimal('0.00'):
            raise ValueError('Base salary must be >= to 0')
        
        self._base_salary = salary

    @override
    def earnings(self):
        """Calculate earnings."""   
        return super().earnings() + self.base_salary

    @override
    def __repr__(self):
        """Return string representation for repr()."""
        return ('Salaried' + super().__repr__() +      
            f'\nbase salary: {self.base_salary:.2f}')

# %%
class SalariedEmployee:
    """An employee who gets paid a fixed weekly salary."""

    def __init__(self, name, weekly_salary):
        """Initialize SalariedEmployee's attributes."""
        self._name = name
        self.weekly_salary = weekly_salary  # validate via property

    @property
    def name(self):
        return self._name

    @property
    def weekly_salary(self):
        return self._weekly_salary

    @weekly_salary.setter
    def weekly_salary(self, salary):
        """Set weekly salary or raise ValueError if invalid."""
        if salary < Decimal('0.00'):
            raise ValueError('Weekly salary must be >= to 0')
        
        self._weekly_salary = salary

    def earnings(self):
        """Calculate earnings."""   
        return self.weekly_salary

    @override
    def __repr__(self):
        """Return string representation for repr()."""
        return (f'SalariedEmployee: {self.name}\n' + 
            f'weekly salary: {self.weekly_salary:.2f}')
    

comm_emp = CommissionEmployee('Sue Jones', Decimal('10000.00'), Decimal('0.06'))
sal_emp = SalariedCommissionEmployee('Bob Lewis',Decimal('5000.00'), Decimal('0.04'), Decimal('300.00'))
new_emp = SalariedEmployee('Pranit Kumar', Decimal('1600.0'))
employees = [comm_emp, sal_emp, new_emp]

for employee in employees:
        print(employee)
        print(f'{employee.earnings():,.2f}\n')
# Out:
# CommissionEmployee: Sue Jones
# gross sales: 10000.00
# commission rate: 0.06
# 600.00
#
# SalariedCommissionEmployee: Bob Lewis
# gross sales: 5000.00
# commission rate: 0.04
# base salary: 300.00
# 500.00
#
# SalariedEmployee: Pranit Kumar
# weekly salary: 1600.00
# 1,600.00
